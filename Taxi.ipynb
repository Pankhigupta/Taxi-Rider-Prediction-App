# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("taxi.csv")
df
# Out:
#     Priceperweek  Population  Monthlyincome  Averageparkingpermonth  \
# 0             15     1800000           5800                      50
# 1             15     1790000           6200                      50
# 2             15     1780000           6400                      60
# 3             25     1778000           6500                      60
# 4             25     1750000           6550                      60
# 5             25     1740000           6580                      70
# 6             25     1725000           8200                      75
# 7             30     1725000           8600                      75
# 8             30     1720000           8800                      75
# 9             30     1705000           9200                      80
# 10            30     1710000           9630                      80
# 11            40     1700000          10570                      80
# 12            40     1695000          11330                      85
# 13            40     1695000          11600                     100
# 14            40     1690000          11800                     105
# 15            40     1630000          11830                     105
# 16            65     1640000          12650                     105
# 17           102     1635000          13000                     110
# 18            75     1630000          13224                     125
# 19            75     1620000          13766                     130
# 20            75     1615000          14010                     150
# 21            80     1605000          14468                     155
# 22            86     1590000          15000                     165
# 23            98     1595000          15200                     175
# 24            87     1590000          15600                     175
# 25            77     1600000          16000                     190
# 26            63     1610000          16200                     200
#
#     Numberofweeklyriders
# 0                 192000
# 1                 190400
# 2                 191200
# 3                 177600
# 4                 176800
# 5                 178400
# 6                 180800
# 7                 175200
# 8                 174400
# 9                 173920
# 10                172800
# 11                163200
# 12                161600
# 13                161600
# 14                160800
# 15                159200
# 16                148800
# 17                115696
# 18                147200
# 19                150400
# 20                152000
# 21                136000
# 22                126240
# 23                123888
# 24                126080
# 25                151680
# 26                152800

# %%
df.isnull().sum()
# Out:
# Priceperweek              0
# Population                0
# Monthlyincome             0
# Averageparkingpermonth    0
# Numberofweeklyriders      0
# dtype: int64

# %%
X=df.iloc[:,:4].values

# %%
y=df.iloc[:,4].values

# %%
plt.plot(df)
# Out:
# [<matplotlib.lines.Line2D at 0x22a24a58a50>,
#  <matplotlib.lines.Line2D at 0x22a24a78b90>,
#  <matplotlib.lines.Line2D at 0x22a24a78cd0>,
#  <matplotlib.lines.Line2D at 0x22a24a78e10>,
#  <matplotlib.lines.Line2D at 0x22a24a78f50>]

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test.round(2))
y_pred
# Out:
# array([139304.00474527, 188458.94116092, 173132.17074341, 139620.10485702,
#        144963.09428358, 164315.40458139])

# %%
y_test
# Out:
# array([151680, 192000, 173920, 152000, 148800, 161600])

# %%
import pickle as pkl

# %%
pkl.dump(lr,open("taxi.pkl","wb"))
print("Model is saved")
# Out:
# Model is saved
